# %% [markdown]
# # PART 2
#
#
# * [HW1 Part 1 Perform Exploratory Data Analysis (EDA) and apply basic statistical concepts to understand the underlying data](./hw1PART1.ipynb)
#
#
#
# * [HW1 Part 2 Explore PDF and CDF with Pandas and Seaborn](./hw1PART2.ipynb)
#
#
#
# * [HW1 Part 3 Explore distance and similarity measures in Pandas and Scikit-learn](./hw1PART3.ipynb)

# %% [markdown]
# ## Steven Doggett 3450-00262 sndoggett9008@muleriders.saumag.edu
# ### MCIS6273_029201S: Data Mining - Fall 2020 Section 029 Short ID 1496201S
# #### Homework 1 PART 2 Due Wednesday 23 September 2020

# %% [markdown]
# in jupyter hub terminal type
#
# wget https://gist.githubusercontent.com/sarchak/b87ad2be315ce05f7a047550646f3c41/raw/0c7d83608111f74f212398fc0d2a704e4f8dc499/diamonds.csv

# %% [markdown]
# https://js-157-41.jetstream-cloud.org (https://js-157-41.jetstream-cloud.org)
#
# https://js-157-41.jetstream-cloud.org/user/stevedoggett/lab? (https://js-157-41.jetstream- cloud.org/user/stevedoggett/lab?)
#
# https://github.com/SteveDoggett/mcis6273_f20_datamining
#
# https://github.com/kmsaumcis/mcis6273_f20_datamining

# %% [markdown]
# Here are the instructions for uploading your homework:
#
# 1) open a terminal in JupyterHub,
#
# 2) if you haven't already, create a directory for all your files (you can do this from the command line or from the Jupyter environment),
#
# 3) with all your files in that directory type the following command in the terminal:
#
# tar cvzf the_name_of_your_homework_submission.tar.gz the_name_of_the_directory_with_your_files/
#
# 4) go back to the notebook file browser, right click the new .tar.gz file and select 'Download'

# %%
import datetime as dt
t1 = dt.datetime.now()
date = t1.strftime("%d") + '-' + t1.strftime("%B") + '-' + t1.strftime("%Y")
time = t1.strftime("%I") + ':' + t1.strftime("%M") + ' ' + t1.strftime("%p")
def header(first, last, ID):
    student = 'Name: ' + first + ' ' + last + ' | ID: ' + ID + ' | Date: ' + date + ' | Time: ' + time
    return student
header('Steven', 'Doggett', '3450-00262')
# Out:
# 'Name: Steven Doggett | ID: 3450-00262 | Date: 23-September-2020 | Time: 09:03 PM'

# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# !pwd
# Out:
# /Users/skynet/Desktop/Doggett_DM_HW1

# %%
# <img src = "SAUlogo.png">

# %% [markdown]
# <img src = "SAUlogo.png">

# %% [markdown]
# # Install in Terminal
#
# pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv("https://gist.githubusercontent.com/sarchak/b87ad2be315ce05f7a047550646f3c41/raw/0c7d83608111f74f212398fc0d2a704e4f8dc499/diamonds.csv")

# df = pd.read_csv("diamonds.csv")

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# ### (35%) Explore PDF and CDF with Pandas and Seaborn

# %% [markdown]
# In the readings and in the lecture there were introductory notions of frequency measures.  Specifically, we
# are interested in  concepts
# relating to the probability of obtaining values in a given distribution.

# %% [markdown]
# Any emperical observations can be plotted in terms of the frequency of their observations.  For example, when looking
# at the number of customers arriving at a restuarant, we often _bin_ the arrivals by hour.  Doing so allows
# us to see how many customers come in over a range of hours allowing a business owner or analyst to
# prepare food, have employees available to work when the arrivals peak or put other business policies in place
# to provide a more pleasant experience for the customers.

# %% [markdown]
# We most often see these plots as _histograms_, and in the case of arrival times by hour, the
# number of bins in which we'd divide the histogram would be the number of hours the restaurant would be open and
# would thus show the aggregate number of customer arrivals each hour of operation.

# %% [markdown]
# Histograms naturally lead us to explore frequencies as probabilities.  Indeed, we might like to understand the probability of 10 customers arriving in an hour, or the probability of more than a certain number of customers.  For example, the probability of more than 20 customers arriving might tell us something interesting about the peak load of customers, etc.  You will note that we have mostly been talking about _discrete_ variables
# -- that is variables that are countable and finite.

# %% [markdown]
# A typical example is the probability of the outcomes of a fair dice. The 6-sided dice has only 6 outcomes, the 8-sided, only
# 8 outcomes and so on.  Thus, we are dealing with a discrete function and so if we let $X$ be an event space, and $x$
# the outcome of the event (roll of a die)
# $x \in X = \{ 1, 2, 3, 4, 5, 6 \}$ then the _probability mass function_ is:

# %% [markdown]
# $$
# \Pr(X=x) = \left\{
# \begin{array}{lr}
# \frac{1}{6} & x = 1\\
# \frac{1}{6} & x= 2\\
# \frac{1}{6} & x= 3\\
# \frac{1}{6} & x= 4\\
# \frac{1}{6} & x= 5\\
# \frac{1}{6} & x= 6\\
# \end{array}
# \right.
# $$

# %% [markdown]
# The histogram for that function is given by:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And you can see rolling a fair dice takes on the same probability for all events, thus is it called a _discrete uniform distribution_.

# %% [markdown]
# The last concept is to develop is that of the of the _cumulative distribution function_ or CDF.  Instead of the probability
# of a specific value, we look at the _cumulative_ probability  at a given value or below.  The output of the CDF
# the probability of obtaining that value or less or $\Pr(X \le x)$.  As you would imagine,
# the CDF grows until it eventually reaches 1.0 -- that is all values at or below that value have a probability of
# 1.

# %% [markdown]
# CDFs are interesting to explore and compare, which is exactly what we would like to do with the diamond data.
# In fact, by comparing CDFs, we can learn a lot about how two distributions compare with one another and
# it is an important tool in developing an undestanding of how the underlying data of two distinct datasets
# might vary.

# %% [markdown]
# To be more concrete, let's look at the trivially simple plot of the CDF for a fair dice.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Similar concepts apply to continous random variables, but we'll stick with the discrete case for this part of the
# assignment.

# %% [markdown]
# &#167;  We want to explore our intuition of the diamonds through the lens of PMF and CDF, so first we're going to
# use a very valuable library called [Seaborn](https://seaborn.pydata.org/) to get a feel for the data and confirm some intuitions.

# %%
# [Seaborn]

# https://seaborn.pydata.org

# %% [markdown]
# The first thing want to do is look at the cumulative distribution of one variable -- _carat_.  Our
# intuition is that different clarities have different carat distributions in the data.  For example, we might
# expect that the lower the clarity, the more distrubuted the carat.  Stated another way, we might find
# more variability in carat sizes as the clarity gets worse.  Let's look at two ends of the spectrum --
# the flawless ("FL") and internally flawlss ("IF") and the opposite end the slightly included "SI2" and "SI3" clarity
# diamonds.  To get started, let's take a look at the distribution of diamond clarity.

# %% [markdown]
# 1. Produce a count of the diamond clarities using the [`pandas.DataFrame.value_counts()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html?highlight=value_counts#pandas.DataFrame.value_counts)
#    method.  Show the
#    count of diamonds on a bar graph using [`plot(kind="bar")`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html?highlight=plot#pandas.DataFrame.plot).

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html?highlight=value_counts#pandas.DataFrame.value_counts

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html?highlight=plot#pandas.DataFrame.plot

# %%
df.groupby('clarity').count()
# Out:
#          carat    cut  color  depth  table  price      x      y      z
# clarity
# I1         741    741    741    741    741    741    741    741    741
# IF        1790   1790   1790   1790   1790   1790   1790   1790   1790
# SI1      13065  13065  13065  13065  13065  13065  13065  13065  13065
# SI2       9194   9194   9194   9194   9194   9194   9194   9194   9194
# VS1       8171   8171   8171   8171   8171   8171   8171   8171   8171
# VS2      12258  12258  12258  12258  12258  12258  12258  12258  12258
# VVS1      3655   3655   3655   3655   3655   3655   3655   3655   3655
# VVS2      5066   5066   5066   5066   5066   5066   5066   5066   5066

# %%
dfclaritycount = df['clarity'].value_counts()

# %%
dfclaritycount
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
dfclaritycount.columns =['Clarity', 'Count']

# %%
type(dfclaritycount)
# Out:
# pandas.core.series.Series

# %%
dfclaritycount = pd.DataFrame([dfclaritycount.rename(None)])

# %%
type(dfclaritycount)
# Out:
# pandas.core.frame.DataFrame

# %%
ax = dfclaritycount.plot.bar(rot=0)

# %%
# I3 is worst clarity, FL is best clarity, ordered from worst to best
clarity_dictinoary = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, 
                "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}

# %%
dfclaritycount
# Out:
#      SI1    VS2   SI2   VS1  VVS2  VVS1    IF   I1
# 0  13065  12258  9194  8171  5066  3655  1790  741

# %%
index = ["I3", "I2", "I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF", "FL"]
count = [ 0  ,  0  ,  741,  9194, 13065, 12258,  8171,   5066,   3655, 1790,   0]
dfclarity = pd.DataFrame({'Count': count}, index=index)
ax = dfclarity.plot.bar(rot=0)

# %% [markdown]
# 2. What observation can you make about the trend in the count of diamonds in each clarity category?

# %% [markdown]
# ## 2. There are 11 total diamond clarity categories but only 8 in this dataset. It looks like a bell shaped normal curve. Nobody purchases FL (best) or I3 (worst) diamonds. The largest demand is for average diamonds SI1 and SI2.

# %% [markdown]
# 3. How do the numbers of diamonds in the "SI" and "IF/FL" groups compare?

# %% [markdown]
# ## 3. There are 13,065 + 9,194 = 22,259 SI diamonds and 1,790 IF/FL diamonds. There are over 12 times as many SI diamonds thant IF/FL diamonds in the dataset.

# %% [markdown]
# &#167;  Now that we have an understanding of how many diamonds we have in each clarity group, let's compare the
# distribution of carats for each.  To do this we are going to turn to Seaborn's `distplot()` method.
# Read about `distplot()` [here](https://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot), but
# this template of code should help you plot what you need:
#
# ```python
#     import seaborn as sns
#     import matlplotlib.pyplot as plt
#
#     plt.title("Comparing Cumulative Distribution of Carat for I1, IF, SI1 and SI2")
#
#     kwargs = {'cumulative': True}
#
#     sns.distplot(the_dataframe_with_clarity_X, hist=False, hist_kws=kwargs, kde_kws=kwargs, label="clarity_X")
#     # repeat for the other clarities you want compare
#
# ```

# %%
# https://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot

# %%
the_dataframe_with_clarity_X = df[['carat','clarity']]

# %%
the_dataframe_with_clarity_SI2 = the_dataframe_with_clarity_X[the_dataframe_with_clarity_X['clarity'] == "SI2"]

# %%
the_dataframe_with_clarity_SI2
# Out:
#        carat clarity
# 0       0.23     SI2
# 4       0.31     SI2
# 13      0.31     SI2
# 14      0.20     SI2
# 16      0.30     SI2
# ...      ...     ...
# 53902   0.77     SI2
# 53915   0.77     SI2
# 53928   0.79     SI2
# 53938   0.86     SI2
# 53939   0.75     SI2
#
# [9194 rows x 2 columns]

# %%
# the_dataframe_with_clarity_X

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# repeat for the other clarities you want compare

# %%
plt.title("Comparing Cumulative Distribution of Carat for I1, IF, SI1 and SI2")
kwargs = {'cumulative': True}
sns.distplot(df.carat)

# %%
sns.distplot(the_dataframe_with_clarity_SI2.carat)

# %%
sns.distplot(df[df['clarity'] == "SI2"].carat)

# %%
plt.title("Comparing Cumulative Distribution of Carat for SI2")
kwargs = {'cumulative': True}
# sns.distplot(df[df['clarity'] == "SI2"].carat)
sns.distplot(df[df['clarity'] == "SI2"].carat, hist=False, 
             hist_kws=kwargs, kde_kws=kwargs, label="clarity_SI2")

# %%
plt.title("Comparing Cumulative Distribution of Carat for SI2")
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == "SI2"].carat)
sns.distplot(df[df['clarity'] == "SI2"].carat, hist=False, 
             hist_kws=kwargs, kde_kws=kwargs, label="clarity_SI2")

# %%
X = "I1"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    741.000000
# mean       1.283846
# std        0.632436
# min        0.300000
# 25%        0.960000
# 50%        1.120000
# 75%        1.510000
# max        5.010000
# Name: carat, dtype: float64

# %%
X = "SI2"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    9194.000000
# mean        1.077648
# std         0.516653
# min         0.200000
# 25%         0.720000
# 50%         1.010000
# 75%         1.260000
# max         3.040000
# Name: carat, dtype: float64

# %%
X = "SI1"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    13065.000000
# mean         0.850482
# std          0.449652
# min          0.210000
# 25%          0.500000
# 50%          0.760000
# 75%          1.060000
# max          2.570000
# Name: carat, dtype: float64

# %%
X = "VS2"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    12258.000000
# mean         0.763935
# std          0.446292
# min          0.200000
# 25%          0.380000
# 50%          0.630000
# 75%          1.020000
# max          3.510000
# Name: carat, dtype: float64

# %%
X = "VS1"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    8171.000000
# mean        0.727158
# std         0.423529
# min         0.230000
# 25%         0.380000
# 50%         0.570000
# 75%         1.010000
# max         2.590000
# Name: carat, dtype: float64

# %%
X = "VVS2"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    5066.000000
# mean        0.596202
# std         0.359697
# min         0.230000
# 25%         0.320000
# 50%         0.440000
# 75%         0.730000
# max         2.070000
# Name: carat, dtype: float64

# %%
X = "VVS1"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat,hist=False,hist_kws=kwargs,kde_kws=kwargs,label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    3655.000000
# mean        0.503321
# std         0.299557
# min         0.230000
# 25%         0.310000
# 50%         0.390000
# 75%         0.560000
# max         2.310000
# Name: carat, dtype: float64

# %%
X = "IF"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    1790.000000
# mean        0.505123
# std         0.313433
# min         0.230000
# 25%         0.310000
# 50%         0.350000
# 75%         0.550000
# max         2.290000
# Name: carat, dtype: float64

# %%
dfclarity
# Out:
#       Count
# I3        0
# I2        0
# I1      741
# SI2    9194
# SI1   13065
# VS2   12258
# VS1    8171
# VVS2   5066
# VVS1   3655
# IF     1790
# FL        0

# %% [markdown]
# You now have a cumulative distribution for each clarity. Figure 5 shows you an example of what **one** of the plots
# might look like.
#
# ![Cumulative distribution plot example](./example_distc_plot_240.png)
#
# ![image.png](attachment:image.png)

# %%
TITLE = "Comparing Cumulative Distribution of Carat for ALL CLARITIES"
plt.title(TITLE)
kwargs = {'cumulative': True}

X = "IF"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "VVS1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "VVS2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "VS1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "VS2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "SI1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "SI2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "I1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

# %%
TITLE = "Comparing Cumulative Distribution of Carat for IF (most expensive & I1 (cheapest) Clarities"
plt.title(TITLE)
kwargs = {'cumulative': True}

X = "IF"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

X = "I1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)

# %%
TITLE = "Comparing Distribution of Carat for IF (most expensive) & I1 (cheapest) CLARITITES" 
plt.title(TITLE)

X = "IF"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "I1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
TITLE = "Comparing Distribution of Carat for IF (most expensive) & I1 (cheapest) CLARITITES" 
plt.title(TITLE)

X = "IF"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VVS1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VVS2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VS1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VS2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "SI1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "SI2"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "I1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
dfclarity
# Out:
#       Count
# I3        0
# I2        0
# I1      741
# SI2    9194
# SI1   13065
# VS2   12258
# VS1    8171
# VVS2   5066
# VVS1   3655
# IF     1790
# FL        0

# %% [markdown]
# You will be reminded that the $y$-axis shows us
# the cumulative probability while the $x$-axis shows us the carat sizes.  The smoothed curve shows the density
# of the carat for a given probability and uses a smoothing technique called _kernel density estimate_.
# After displaying the plot from the
# code above in your notebook, answer the following questions:

# %% [markdown]
# 1. Which clarity has the largest relative distribution of high carat diamonds?

# %% [markdown]
# ## 1. Clarity I1 (cheapest clarity) has the largest relative distribution of high carat diamonds with a standard deviation of 0.632436 carats with most consumers preferring a ~ 1.283846 carat diamond. USING DEFINITION OF LARGE DIAMOND AS > 1 CARAT.

# %%
TITLE = "Comparing Distribution of Carat for 2 CLARITITES" 
plt.title(TITLE)

X = "SI1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "I1"
LABEL = "Clarity" + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
X = "I1"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    741.000000
# mean       1.283846
# std        0.632436
# min        0.300000
# 25%        0.960000
# 50%        1.120000
# 75%        1.510000
# max        5.010000
# Name: carat, dtype: float64

# %% [markdown]
# 2. Which has the largest relative distribution of small diamonds?

# %% [markdown]
# ## 2. Clarity IF (most expensie) has the largest relative distribution of small diamonds with a standard deviation of 0.313433 with most consumers being able to afford a ~ 0.505123 carat diamond. USING DEFINITION OF SMALL DIAMOND AS 1/2 CARAT.

# %%
TITLE = "Comparing Distribution of Carat for 3 CLARITITES" 
plt.title(TITLE)

X = "IF"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VS1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VS2"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
X = "IF"
TITLE = "Comparing Cumulative Distribution of Carat for Clarity " + X
LABEL = "Clarity" + X
plt.title(TITLE)
kwargs = {'cumulative': True}
sns.distplot(df[df['clarity'] == X].carat)
sns.distplot(df[df['clarity'] == X].carat, hist=False, hist_kws=kwargs, kde_kws=kwargs, label=LABEL)
print(df[df['clarity'] == X].carat.describe())
# Out:
# count    1790.000000
# mean        0.505123
# std         0.313433
# min         0.230000
# 25%         0.310000
# 50%         0.350000
# 75%         0.550000
# max         2.290000
# Name: carat, dtype: float64

# %% [markdown]
# 3. Based on the prior two questions, is this a surprising outcome?

# %% [markdown]
# ## 3. No, it is not a surprising outcome. Purchasers of diamonds can afford Big Carat & Cheap Clarity or Small Carat & Expensive Clarity.

# %% [markdown]
# 4. Which two distributions look most similar?

# %% [markdown]
# ## 4. Several groups of two distributions look similar but the 2 most similar in the plots below appear to be Clarities VS1 and VS2.
#
# IF and VVS1 are also quite similar.
#
# SI1 and SI2 are quite DISSSIMILAR.

# %%
TITLE = "Comparing Distribution of Carat for 2 CLARITITES" 
plt.title(TITLE)

X = "VS1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VS2"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
TITLE = "Comparing Distribution of Carat for 2 CLARITITES" 
plt.title(TITLE)

X = "VVS1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VVS2"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
TITLE = "Comparing Distribution of Carat for 2 CLARITITES" 
plt.title(TITLE)

X = "SI1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "SI2"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %%
TITLE = "Comparing Distribution of Carat for 2 CLARITITES" 
plt.title(TITLE)

X = "IF"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

X = "VVS1"
LABEL = "Clarity " + X
sns.distplot(df[df['clarity'] == X].carat, hist=False, label=LABEL)

# %% [markdown]
# &#167;  We're now at the point where we'd like to graph this same data in two dimensions, with what is
# called the _kernel density estimate plot_ or KDE plot.  The KDE plot takes our bivariate data as input and
# outputs a smoothed 2D contour plot.  You see, in the example above, we only showed a single feature of the
# data.  While interesting, it is far more interesting when we compare two variables.  Indeed, since
# diamonds are generally considered a luxury item, and not typically considered "inexpensive", we might like
# to know how _carat_ size influences _price_.  This makes things a bit more interesting and useful.

# %% [markdown]
# We're going to use the KDE plot to visually compare the densities of _carat_ and _price_.
#
# ```python
#     plt.title("KDE Plot of Price to Carat for X and Y")
#
#     # dataset X
#     sns.kdeplot(
#         x_carat,
#         x_price,
#         cmap="Reds",
#         shade=True,
#         shade_lowest=False, label="x_label")
#
#     # dataset Y
#     sns.kdeplot(
#         y_carat,
#         y_price,
#         cmap="Blues",
#         shade=True,
#         shade_lowest=False, label="y_label")
#
#     plt.legend()
#     plt.savefig("your_plot_can_be_saved.png")
# ```

# %%
X = "IF"
x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price

Y = "IF"
y_carat = df[df['clarity'] == Y].carat
y_price = df[df['clarity'] == Y].price

plt.title("KDE Plot of Price to Carat for Clarities " + X + " & " + Y)

# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)

# dataset Y
YLABEL = "Clarity " + Y
sns.kdeplot(
y_carat,
y_price,
cmap="Reds",
shade=True,
shade_lowest=False, label = YLABEL)

plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %% [markdown]
# Your plot will look something like that in Figure 3 below.  If you notice in the figure the densities show
# that SI2 has a broad distribution between a depth of 58 and 65, while the price varies greatly reaching
# well above $10,000.  You can see IF diamonds are much tighter both in terms of price and depth.
#
# ![KDE Plot for depth vs. price (SI2 and IF clarity)](./2d_kde_plot.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# You may want to only plot each alone or no more than 2 per plot so you can see the data.
# After you have the plots, make sure you save them and include them in your zipped submission.  Then answer the
# questions below based on your plots:

# %%
X = "IF"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "VVS1"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "VVS2"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "VS1"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "VS2"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "SI1"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "SI2"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
X = "I1"

x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price
plt.title("KDE Plot of Price to Carat for Clarity " + X)
# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)
plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %% [markdown]
# 1. How do the density plots compare to one another?  What general observation can you make
#    about the typical SI1 and SI2 diamonds?  What are their similarities?

# %%
X = "SI1"
x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price

Y = "SI2"
y_carat = df[df['clarity'] == Y].carat
y_price = df[df['clarity'] == Y].price

plt.title("KDE Plot of Price to Carat for Clarities " + X + " & " + Y)

# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)

# dataset Y
YLABEL = "Clarity " + Y
sns.kdeplot(
y_carat,
y_price,
cmap="Reds",
shade=True,
shade_lowest=False, label = YLABEL)

plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %%
## SI1 and SI2 diamonds have similar KDE plots of price to carat. 
## Both of these clarities are priced similarly per carat size.

# %% [markdown]
# 2. What about the density plots for I1 and IF?  How are they different?  Please provide
#    as much description to support your answer.

# %%
X = "I1"
x_carat = df[df['clarity'] == X].carat
x_price = df[df['clarity'] == X].price

Y = "IF"
y_carat = df[df['clarity'] == Y].carat
y_price = df[df['clarity'] == Y].price

plt.title("KDE Plot of Price to Carat for Clarities " + X + " & " + Y)

# dataset X
XLABEL = "Clarity " + X
sns.kdeplot(
x_carat,
x_price,
cmap="Blues",
shade=True,
shade_lowest=False, label = XLABEL)

# dataset Y
YLABEL = "Clarity " + Y
sns.kdeplot(
y_carat,
y_price,
cmap="Reds",
shade=True,
shade_lowest=False, label = YLABEL)

plt.legend()
plt.savefig("your_plot_can_be_saved.png")

# %% [markdown]
# ## I1 (cheapest quality) and IF (most expensive highest qualtity) have very different KDE plots. IF diamonds are in general small, less than 1/2 carat with a small distribution of price less than USD 2000.  I1 diamonds vary from 1/2 carat to over 2 carats with a price range from USD 500 up to USD 7500.

# %% [markdown]
# 3. From the plots alone, what can you make of the price density of 1-carat SI1 diamonds versus those
#    of SI2 diamonds?

# %% [markdown]
# ## The price density of 1-carat SI1 diamonds USD 4900 vs SI2 diamonds USD 5100 are similar. Both SI1 and SI2 1-carat diamonds cost about USD 5 grand.

# %% [markdown]
# 4. What would you say of the claim: "If clarity is of great concern to you, the your best value diamonds are in
#    found in the I1 clarity."?  What challenges could you make to this claim based on the KDE plots?  What
#    are the supports for this claim?

# %% [markdown]
# ## The best value diamonds are I1 if clarity is NOT of great concern. With I1 you can buy a 2-carat diamond for USD 7500. A 2-carat diamond may be prohibitily expensive in other clarities.

# %% [markdown]
# 5. Write a query using the [`DataFrame.query()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html)
#    method to show the descriptive statistics for _clarity I1_ and _clarity SI1_ diamonds.  You can use the [`DataFrame.describe()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html?highlight=describe#pandas.DataFrame.describe)
#    method to get the descriptive statistics.  The query method will restrict diamonds between .95 and 1.05 carats
#    for each color.

# %%
dfx = df[(df['carat'] >= 0.95) & (df['carat'] <= 1.05)]

# %%
dfx[dfx['clarity'] == 'I1'].describe()
# Out:
#             carat       depth       table       price           x           y  \
# count  160.000000  160.000000  160.000000   160.00000  160.000000  160.000000
# mean     1.006688   62.381250   58.556250  2687.35625    6.396000    6.342500
# std      0.025072    2.932237    2.576495   602.89209    0.144476    0.178484
# min      0.950000   56.100000   53.000000  1262.00000    5.720000    5.590000
# 25%      1.000000   61.000000   57.000000  2216.50000    6.330000    6.260000
# 50%      1.010000   61.800000   58.000000  2794.50000    6.410000    6.390000
# 75%      1.020000   63.125000   60.000000  3172.00000    6.482500    6.460000
# max      1.050000   78.200000   66.000000  3987.00000    6.700000    6.690000
#
#                 z
# count  160.000000
# mean     3.946312
# std      0.332279
# min      0.000000
# 25%      3.920000
# 50%      3.980000
# 75%      4.020000
# max      4.420000

# %%
dfx[dfx['clarity'] == 'SI1'].describe()
# Out:
#              carat        depth        table        price            x  \
# count  1833.000000  1833.000000  1833.000000  1833.000000  1833.000000
# mean      1.012493    61.921331    58.209765  4874.370431     6.417938
# std       0.017303     1.884320     2.289164   673.953337     0.110280
# min       0.950000    43.000000    50.000000  2323.000000     6.000000
# 25%       1.000000    60.900000    57.000000  4469.000000     6.350000
# 50%       1.010000    62.100000    58.000000  4879.000000     6.410000
# 75%       1.020000    63.000000    60.000000  5322.000000     6.490000
# max       1.050000    70.600000    67.000000  7564.000000     6.840000
#
#                  y            z
# count  1833.000000  1833.000000
# mean      6.413846     3.971997
# std       0.116083     0.072376
# min       5.880000     3.660000
# 25%       6.350000     3.940000
# 50%       6.420000     3.980000
# 75%       6.490000     4.020000
# max       6.770000     4.270000

# %% [markdown]
# 6. Based on that query how can it be used as evidence to support the original claim in question #4 previously?

# %% [markdown]
# ## The mean price of ~ 1-carat SI1 diamond = USD 4874 while the mean price of a ~ 1-carat I1 diamond = USD 2687. The SI1 diamond is 1.8 times more expensive thatn the I1 diamond.

# %% [markdown]
# # END OF PART 2
#
#
# * [HW1 Part 1 Perform Exploratory Data Analysis (EDA) and apply basic statistical concepts to understand the underlying data](./hw1PART1.ipynb)
#
#
#
# * [HW1 Part 2 Explore PDF and CDF with Pandas and Seaborn](./hw1PART2.ipynb)
#
#
#
# * [HW1 Part 3 Explore distance and similarity measures in Pandas and Scikit-learn](./hw1PART3.ipynb)
